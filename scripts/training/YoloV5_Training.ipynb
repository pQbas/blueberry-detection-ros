# %%
# !nvidia-smi
# Out:
# Thu Jun  1 00:23:33 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   47C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-174-g5eb7f7d Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.3/78.2 GB disk)

# %%
# !sudo apt-get install unzip
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# unzip is already the newest version (6.0-25ubuntu1.1).
# 0 upgraded, 0 newly installed, 0 to remove and 34 not upgraded.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp /content/drive/MyDrive/BlueBerry/dataset_29_05.zip /content/
# !unzip -q /content/dataset_29_05.zip

# %%
# !mkdir dataset
# !mv test dataset
# !mv train dataset
# !mv valid dataset

# %%
content = """lr0: 0.01  # initial learning rate (SGD=1E-2, Adam=1E-3)
lrf: 0.01  # final OneCycleLR learning rate (lr0 * lrf)
momentum: 0.937  # SGD momentum/Adam beta1
weight_decay: 0.0005  # optimizer weight decay 5e-4
warmup_epochs: 3.0  # warmup epochs (fractions ok)
warmup_momentum: 0.8  # warmup initial momentum
warmup_bias_lr: 0.1  # warmup initial bias lr
box: 0.05  # box loss gain
cls: 0.5  # cls loss gain
cls_pw: 1.0  # cls BCELoss positive_weight
obj: 1.0  # obj loss gain (scale with pixels)
obj_pw: 1.0  # obj BCELoss positive_weight
iou_t: 0.20  # IoU training threshold
anchor_t: 4.0  # anchor-multiple threshold
# anchors: 3  # anchors per output layer (0 to ignore)
fl_gamma: 0.0  # focal loss gamma (efficientDet default gamma=1.5)
hsv_h: 0.01  # image HSV-Hue augmentation (fraction)
hsv_s: 0.01  # image HSV-Saturation augmentation (fraction)
hsv_v: 0.01  # image HSV-Value augmentation (fraction)
degrees: 0.2  # image rotation (+/- deg)
translate: 0.1  # image translation (+/- fraction)
scale: 0.1  # image scale (+/- gain)
shear: 0.0  # image shear (+/- deg)
perspective: 0.0  # image perspective (+/- fraction), range 0-0.001
flipud: 0.5  # image flip up-down (probability)
fliplr: 0.5  # image flip left-right (probability)
mosaic: 0.5  # image mosaic (probability)
mixup: 0.0  # image mixup (probability)
copy_paste: 0.5  # segment copy-paste (probability)"""

filename = "data/hyps/hyp.custom.yaml"

with open(filename, "w") as file:
    file.write(content)

# %%
content = """# Train/val/test sets as 1) dir: path/to/imgs, 2) file: path/to/imgs.txt, or 3) list: [path/to/imgs1, path/to/imgs2, ..]
path: dataset/  # dataset root dir
train: train/  # train images (relative to 'path') 128 images
val: valid/  # val images (relative to 'path') 128 images
test: test/ # test images (optional)

# Classes
names:
  0: blueberry"""

filename = "data/custom.yaml"

with open(filename, "w") as file:
    file.write(content)

# %%
# %cd yolov5
# !python3 segment/train.py --img 640 --batch 5 --epochs 100 --weights yolov5m-seg.pt --hyp hyp.custom.yaml --data custom.yaml --name experiment_4 --cache
# Out:
# [Errno 2] No such file or directory: 'yolov5'
# /content/yolov5
# segment/train: weights=yolov5m-seg.pt, cfg=, data=custom.yaml, hyp=hyp.custom.yaml, epochs=100, batch_size=5, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train-seg, name=experiment_4, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, mask_ratio=4, no_overlap=False
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-174-g5eb7f7d Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %%
# !cp -r /content/yolov5/runs/train-seg/experiment_4 /content/drive/MyDrive/BlueBerry

# %%
print("Hello")
# Out:
# Hello

# %% [markdown]
# # **Set of experiments N°1**

# %% [markdown]
# ### Dataset
#     - Synthetic: 100%
#     - Real: 0%
#
# ### Training
#     - Epochs: 50
#     - Batch-size: 5
#
# ### Model:
#     - Yolov7: Medium

# %%
# %cd yolov5
# !python3 segment/train.py --img 640 --batch 5 --epochs 300 --weights yolov5l-seg.pt --data custom.yaml --name experiment_1 --cache
# Out:
# [Errno 2] No such file or directory: 'yolov5'
# /content/yolov5
# segment/train: weights=yolov5l-seg.pt, cfg=, data=custom.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=900, batch_size=5, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train-seg, name=experiment_1, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, mask_ratio=4, no_overlap=False
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-172-gc3c1304 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %%
# !cp -r /content/yolov5/runs/train-seg/experiment_1 /content/drive/MyDrive/BlueBerryNet

# %% [markdown]
# ### Dataset
#     - Synthetic: 100%
#     - Real: 0%
#
# ### Training
#     - Epochs: 150
#     - Batch-size: 5
#
# ### Model:
#     - Yolov7: Small

# %%
# %cd yolov5
# !python3 segment/train.py --img 640 --batch 5 --epochs 300 --weights yolov5m-seg.pt --data custom.yaml --name experiment_2 --cache
# Out:
# [Errno 2] No such file or directory: 'yolov5'
# /content/yolov5
# segment/train: weights=yolov5m-seg.pt, cfg=, data=custom.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=300, batch_size=5, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train-seg, name=experiment_2, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, mask_ratio=4, no_overlap=False
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-172-gc3c1304 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %% [markdown]
# # **Set of experiments N°2**

# %% [markdown]
# ### Dataset
#     - Synthetic: 100%
#     - Real: 0%
#
# ### Training
#     - Epochs: 50
#     - Batch-size: 5
#
# ### Model:
#     - Yolov7: Large

# %%
# %cd yolov5
# !python3 segment/train.py --img 640 --batch 5 --epochs 150 --weights yolov5l-seg.pt --data data/custom.yaml --name experiment_2_1 --cache
# Out:
# [Errno 2] No such file or directory: 'yolov5'
# /notebooks/yolov5
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout)
# wandb: W&B disabled due to login timeout.
# ...
